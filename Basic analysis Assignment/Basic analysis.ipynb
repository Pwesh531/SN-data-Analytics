# %%
import pandas as pd

# %%
#Reading the original data
Res = pd.read_csv('data.csv', encoding = 'unicode_escape')
Res
# Out:
#                                                  Details  \
# 0                A Beautiful home with so much to offer!
# 1                        Designed for Worry-free Living.
# 2      Well Positioned Plot in Popular Kelderhof with...
# 3               "Towering Townhouse" direct beach access
# 4                                    Neat beautiful Home
# ...                                                  ...
# 13214           A beautiful home with little maintainace
# 13215    Superb locality....buy direct from developer!!!
# 13216  Beautiful property and perfect to raise your k...
# 13217                                        New Release
# 13218    2 Bedroom, 2 Bathroom apartment on Diaz beach..
#
#                                              Address        Price  \
# 0                              Mondeor, 183 Colworth   R1,749,000
# 1                                          Equestria   R1,440,000
# 2      Kelderhof Country Village, 1 Livingstone Road   R1,250,000
# ...

# %%
#To get details of the data to check what optimizations could be carried out to reduce memory
Res.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13219 entries, 0 to 13218
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Details            13219 non-null  object
#  1   Address            13219 non-null  object
#  2   Price              13216 non-null  object
#  3   NumberOfBedrooms   13219 non-null  object
#  4   NumberOfBathrooms  13219 non-null  object
#  5   NumberOfToilets    13219 non-null  object
#  6   NumberOfCarSpace   13219 non-null  object
# dtypes: object(7)
# memory usage: 723.0+ KB

# %%
#Renaming some of the column names
Res.columns = ['Description', 'Address', 'Price(Rands)', 'Bedrooms', 'Bathrooms', 'Toilets', 'Garage']

# %%
Res
# Out:
#                                              Description  \
# 0                A Beautiful home with so much to offer!
# 1                        Designed for Worry-free Living.
# 2      Well Positioned Plot in Popular Kelderhof with...
# 3               "Towering Townhouse" direct beach access
# 4                                    Neat beautiful Home
# ...                                                  ...
# 13214           A beautiful home with little maintainace
# 13215    Superb locality....buy direct from developer!!!
# 13216  Beautiful property and perfect to raise your k...
# 13217                                        New Release
# 13218    2 Bedroom, 2 Bathroom apartment on Diaz beach..
#
#                                              Address Price(Rands)    Bedrooms  \
# 0                              Mondeor, 183 Colworth   R1,749,000  3 Bedrooms
# 1                                          Equestria   R1,440,000  2 Bedrooms
# ...

# %%
#Removing the 'R'in the prices and dropping all 'Nan' values
Res['Price(Rands)'] = Res['Price(Rands)'].str.replace('R', '' )
Res['Price(Rands)'] = Res['Price(Rands)'].str.replace(',', '')
Res.drop(3, inplace= True)
Res.dropna(subset= ['Price(Rands)'], inplace = True)

# %%
Res
# Out:
#                                              Description  \
# 0                A Beautiful home with so much to offer!
# 1                        Designed for Worry-free Living.
# 2      Well Positioned Plot in Popular Kelderhof with...
# 4                                    Neat beautiful Home
# 5                                Luxury met Tranquility!
# ...                                                  ...
# 13214           A beautiful home with little maintainace
# 13215    Superb locality....buy direct from developer!!!
# 13216  Beautiful property and perfect to raise your k...
# 13217                                        New Release
# 13218    2 Bedroom, 2 Bathroom apartment on Diaz beach..
#
#                                              Address Price(Rands)    Bedrooms  \
# 0                              Mondeor, 183 Colworth      1749000  3 Bedrooms
# 1                                          Equestria      1440000  2 Bedrooms
# ...

# %%
## To replace rows in the 'price' column which contains strings into an empty string

# %%
Res['Price(Rands)'] = Res['Price(Rands)'].str.replace('Bidding to start from', '')

# %%
Res['Price(Rands)'] = Res['Price(Rands)'].str.replace('!!! Live Auction!', '')

# %%
#
Res['Price(Rands)'] = Res['Price(Rands)'].str.replace('POA', '')

# %%
Res['Price(Rands)'] = Res['Price(Rands)'].str.replace('plus VA', '')

# %%
#
Res['Price(Rands)'] = Res['Price(Rands)'].str.replace('Price on Applicati', '')

# %%
Res['Price(Rands)'] = Res['Price(Rands)'].str.replace('Price by Negotiation over', '')

# %%
#
Res['Price(Rands)'] = Res['Price(Rands)'].str.replace('SERIOUS SELLER', '')

# %%
Res['Price(Rands)'] = Res['Price(Rands)'].str.replace('From', '')

# %%
#
Res['Price(Rands)'] = Res['Price(Rands)'].str.replace('Price by Negotiati', '')

# %%
#
Res['Price(Rands)'] = Res['Price(Rands)'].str.replace('Auction 31 Mar 2021', '')

# %%
#
Res['Price(Rands)'] = Res['Price(Rands)'].str.replace('Under O', '')

# %%
Res['Price(Rands)'] = Res['Price(Rands)'].str.replace('SOL', '')

# %%
Res['Price(Rands)'] = Res['Price(Rands)'].str.replace('REDUCE', '')

# %%
Res['Price(Rands)'] = Res['Price(Rands)'].str.replace('Welcoming O', '')

# %%
Res['Price(Rands)'] = Res['Price(Rands)'].str.replace('Auction 15 Jul 2021', '')

# %%
Res['Price(Rands)'] = Res['Price(Rands)'].str.replace('Auction 22 Jul 2021', '')

# %%
Res['Price(Rands)'] = Res['Price(Rands)'].str.replace('FROM', '')

# %%
Res['Price(Rands)'] = Res['Price(Rands)'].str.replace('Auction 08 Jul 2021', '')

# %%
Res['Price(Rands)'] = Res['Price(Rands)'].str.replace('Priced From', '')

# %%
Res['Price(Rands)'] = Res['Price(Rands)'].str.replace('Offers form', '')

# %%
Res['Price(Rands)'] = Res['Price(Rands)'].str.replace('Auction 30 Jul 2021', '')

# %%
Res['Price(Rands)'] = Res['Price(Rands)'].str.replace('SOLD BY HARCOURTS', '')

# %%
Res['Price(Rands)'] = Res['Price(Rands)'].str.replace('SALE IN PROGRESS HARCOURTS', '')

# %%
Res['Price(Rands)'] = Res['Price(Rands)'].str.replace('Back on the Market!', '')

# %%
Res['Price(Rands)'] = Res['Price(Rands)'].str.replace('PRICE REDUCE', '')

# %%
Res['Price(Rands)'] = Res['Price(Rands)'].str.replace('RANSACTION IN PROGRESS', '')

# %%
Res
# Out:
#                                              Description  \
# 0                A Beautiful home with so much to offer!
# 1                        Designed for Worry-free Living.
# 2      Well Positioned Plot in Popular Kelderhof with...
# 4                                    Neat beautiful Home
# 5                                Luxury met Tranquility!
# ...                                                  ...
# 13214           A beautiful home with little maintainace
# 13215    Superb locality....buy direct from developer!!!
# 13216  Beautiful property and perfect to raise your k...
# 13217                                        New Release
# 13218    2 Bedroom, 2 Bathroom apartment on Diaz beach..
#
#                                              Address Price(Rands)    Bedrooms  \
# 0                              Mondeor, 183 Colworth      1749000  3 Bedrooms
# 1                                          Equestria      1440000  2 Bedrooms
# ...

# %%
#To extract only the number in the bedrooms, bathrooms, toilets and garage columns and convert 
#them to intgers or foat as the case may be

Res['Bedrooms']=Res['Bedrooms'].str.split(' ').str.get(0). astype('int')

# %%
Res
# Out:
#                                              Description  \
# 0                A Beautiful home with so much to offer!
# 1                        Designed for Worry-free Living.
# 2      Well Positioned Plot in Popular Kelderhof with...
# 4                                    Neat beautiful Home
# 5                                Luxury met Tranquility!
# ...                                                  ...
# 13214           A beautiful home with little maintainace
# 13215    Superb locality....buy direct from developer!!!
# 13216  Beautiful property and perfect to raise your k...
# 13217                                        New Release
# 13218    2 Bedroom, 2 Bathroom apartment on Diaz beach..
#
#                                              Address Price(Rands)  Bedrooms  \
# 0                              Mondeor, 183 Colworth      1749000         3
# 1                                          Equestria      1440000         2
# ...

# %%
Res['Bathrooms']=Res['Bathrooms'].str.split(' ').str.get(0). astype('float')

# %%
Res
# Out:
#                                              Description  \
# 0                A Beautiful home with so much to offer!
# 1                        Designed for Worry-free Living.
# 2      Well Positioned Plot in Popular Kelderhof with...
# 4                                    Neat beautiful Home
# 5                                Luxury met Tranquility!
# ...                                                  ...
# 13214           A beautiful home with little maintainace
# 13215    Superb locality....buy direct from developer!!!
# 13216  Beautiful property and perfect to raise your k...
# 13217                                        New Release
# 13218    2 Bedroom, 2 Bathroom apartment on Diaz beach..
#
#                                              Address Price(Rands)  Bedrooms  \
# 0                              Mondeor, 183 Colworth      1749000         3
# 1                                          Equestria      1440000         2
# ...

# %%
Res['Toilets']=Res['Toilets'].str.split(' ').str.get(0). astype('int')

# %%
Res
# Out:
#                                              Description  \
# 0                A Beautiful home with so much to offer!
# 1                        Designed for Worry-free Living.
# 2      Well Positioned Plot in Popular Kelderhof with...
# 4                                    Neat beautiful Home
# 5                                Luxury met Tranquility!
# ...                                                  ...
# 13214           A beautiful home with little maintainace
# 13215    Superb locality....buy direct from developer!!!
# 13216  Beautiful property and perfect to raise your k...
# 13217                                        New Release
# 13218    2 Bedroom, 2 Bathroom apartment on Diaz beach..
#
#                                              Address Price(Rands)  Bedrooms  \
# 0                              Mondeor, 183 Colworth      1749000         3
# 1                                          Equestria      1440000         2
# ...

# %%
Res['Garage']=Res['Garage'].str.split(' ').str.get(0). astype('int')

# %%
Res
# Out:
#                                              Description  \
# 0                A Beautiful home with so much to offer!
# 1                        Designed for Worry-free Living.
# 2      Well Positioned Plot in Popular Kelderhof with...
# 4                                    Neat beautiful Home
# 5                                Luxury met Tranquility!
# ...                                                  ...
# 13214           A beautiful home with little maintainace
# 13215    Superb locality....buy direct from developer!!!
# 13216  Beautiful property and perfect to raise your k...
# 13217                                        New Release
# 13218    2 Bedroom, 2 Bathroom apartment on Diaz beach..
#
#                                              Address Price(Rands)  Bedrooms  \
# 0                              Mondeor, 183 Colworth      1749000         3
# 1                                          Equestria      1440000         2
# ...

# %%
#After converting the values in the bedroom, bathroom, toilet and garage column into 
#float/int, the file size of the data was seen to reduce by about 7%

Res.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13215 entries, 0 to 13218
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Description   13215 non-null  object
#  1   Address       13215 non-null  object
#  2   Price(Rands)  13215 non-null  object
#  3   Bedrooms      13215 non-null  int32
#  4   Bathrooms     13215 non-null  float64
#  5   Toilets       13215 non-null  int32
#  6   Garage        13215 non-null  int32
# dtypes: float64(1), int32(3), object(3)
# memory usage: 671.1+ KB

# %%
# Converting the residential description and address as index
Res= Res.set_index(keys = ['Description', 'Address'])

# %%
Res
# Out:
#                                                                                                  Price(Rands)  \
# Description                                        Address
# A Beautiful home with so much to offer!            Mondeor, 183 Colworth                              1749000
# Designed for Worry-free Living.                    Equestria                                          1440000
# Well Positioned Plot in Popular Kelderhof with ... Kelderhof Country Village, 1 Livingstone Road      1250000
# Neat beautiful Home                                Ridgeway                                           1400000
# Luxury met Tranquility!                            Langebaan Country Estate, 1191 Dolphyn Close       3295000
# ...                                                                                                       ...
# A beautiful home with little maintainace           Selcourt                                           1300000
# ...

# %%
Res.to_csv('data2.csv', index= True, header=True)
